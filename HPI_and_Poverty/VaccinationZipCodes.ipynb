# %%
import pandas as pd
import os
import requests

# %%
df = pd.read_csv("Resources/COVID19VaccineRecods.csv", low_memory=False, encoding='utf-8')

# %%
df.head()
# Out:
#    _id  as_of_date  zip_code_tabulation_area local_health_jurisdiction  \
# 0    1  2021-01-12                     93618                    Tulare
# 1    2  2021-01-12                     95437                 Mendocino
# 2    3  2021-01-12                     95991                    Sutter
# 3    4  2021-01-12                     93444           San Luis Obispo
# 4    5  2021-01-12                     95039                  Monterey
#
#             county  vaccine_equity_metric_quartile  \
# 0           Tulare                             1.0
# 1        Mendocino                             2.0
# 2           Sutter                             1.0
# 3  San Luis Obispo                             3.0
# 4         Monterey                             1.0
#
#                    vem_source  age12_plus_population  age5_plus_population  \
# 0  Healthy Places Index Score                24482.3                 28588
# 1  Healthy Places Index Score                12595.5                 13932
# 2  Healthy Places Index Score                33300.8                 37870
# 3  Healthy Places Index Score                18951.8                 20522
# 4     CDPH-Derived ZCTA Score                  860.0                  1032
#
#    tot_population  persons_fully_vaccinated  persons_partially_vaccinated  \
# 0         31470.0                      51.0                         252.0
# 1         14859.0                      66.0                         317.0
# 2         40861.0                     114.0                         835.0
# 3         21331.0                     155.0                         441.0
# 4          1074.0                       NaN                           NaN
#
#    percent_of_population_fully_vaccinated  \
# 0                                0.001621
# 1                                0.004442
# 2                                0.002790
# 3                                0.007266
# 4                                     NaN
#
#    percent_of_population_partially_vaccinated  \
# 0                                    0.008008
# 1                                    0.021334
# 2                                    0.020435
# 3                                    0.020674
# 4                                         NaN
#
#    percent_of_population_with_1_plus_dose  up_to_date_count  \
# 0                                0.009629                 0
# 1                                0.025776                 0
# 2                                0.023225                 0
# 3                                0.027940                 0
# 4                                     NaN                 0
#
#                                             redacted
# 0  Information redacted in accordance with CA sta...
# 1  Information redacted in accordance with CA sta...
# 2  Information redacted in accordance with CA sta...
# 3  Information redacted in accordance with CA sta...
# 4  Information redacted in accordance with CA sta...

# %%
# Define a dictionary to map the old column names to new names
renamed_columns = {
    '_id': 'ID',
    'as_of_date': 'Date',
    'zip_code_tabulation_area': 'Zip Code',
    'local_health_jurisdiction': 'Health Jurisdiction',
    'county': 'County Name',
    'vaccine_equity_metric_quartile': 'Vaccine Quartile',
    'vem_source': 'Vaccine Source',
    'age12_plus_population': 'Age 12+ Population',
    'age5_plus_population': 'Age 5+ Population',
    'tot_population': 'Total Population',
    'persons_fully_vaccinated': 'Fully Vaccinated',
    'persons_partially_vaccinated': 'Partially Vaccinated',
    'percent_of_population_fully_vaccinated': 'Percent Fully Vaccinated',
    'percent_of_population_partially_vaccinated': 'Percent Partially Vaccinated',
    'percent_of_population_with_1_plus_dose': 'Percent With 1+ Dose',
    'up_to_date_count': 'Up To Date Count',
    'redacted': 'Redacted Info'
}

# Use the rename method to apply the column name mapping
df.rename(columns=renamed_columns, inplace=True)

# Display the DataFrame with renamed columns
df.head()
# Out:
#    ID        Date  Zip Code Health Jurisdiction      County Name  \
# 0   1  2021-01-12     93618              Tulare           Tulare
# 1   2  2021-01-12     95437           Mendocino        Mendocino
# 2   3  2021-01-12     95991              Sutter           Sutter
# 3   4  2021-01-12     93444     San Luis Obispo  San Luis Obispo
# 4   5  2021-01-12     95039            Monterey         Monterey
#
#    Vaccine Quartile              Vaccine Source  Age 12+ Population  \
# 0               1.0  Healthy Places Index Score             24482.3
# 1               2.0  Healthy Places Index Score             12595.5
# 2               1.0  Healthy Places Index Score             33300.8
# 3               3.0  Healthy Places Index Score             18951.8
# 4               1.0     CDPH-Derived ZCTA Score               860.0
#
#    Age 5+ Population  Total Population  Fully Vaccinated  \
# 0              28588           31470.0              51.0
# 1              13932           14859.0              66.0
# 2              37870           40861.0             114.0
# 3              20522           21331.0             155.0
# 4               1032            1074.0               NaN
#
#    Partially Vaccinated  Percent Fully Vaccinated  \
# 0                 252.0                  0.001621
# 1                 317.0                  0.004442
# 2                 835.0                  0.002790
# 3                 441.0                  0.007266
# 4                   NaN                       NaN
#
#    Percent Partially Vaccinated  Percent With 1+ Dose  Up To Date Count  \
# 0                      0.008008              0.009629                 0
# 1                      0.021334              0.025776                 0
# 2                      0.020435              0.023225                 0
# 3                      0.020674              0.027940                 0
# 4                           NaN                   NaN                 0
#
#                                        Redacted Info
# 0  Information redacted in accordance with CA sta...
# 1  Information redacted in accordance with CA sta...
# 2  Information redacted in accordance with CA sta...
# 3  Information redacted in accordance with CA sta...
# 4  Information redacted in accordance with CA sta...

# %%
# Delete the last column
df = df.drop(df.columns[-1], axis=1)

# %%
df.head()
# Out:
#    ID        Date  Zip Code Health Jurisdiction      County Name  \
# 0   1  2021-01-12     93618              Tulare           Tulare
# 1   2  2021-01-12     95437           Mendocino        Mendocino
# 2   3  2021-01-12     95991              Sutter           Sutter
# 3   4  2021-01-12     93444     San Luis Obispo  San Luis Obispo
# 4   5  2021-01-12     95039            Monterey         Monterey
#
#    Vaccine Quartile              Vaccine Source  Age 12+ Population  \
# 0               1.0  Healthy Places Index Score             24482.3
# 1               2.0  Healthy Places Index Score             12595.5
# 2               1.0  Healthy Places Index Score             33300.8
# 3               3.0  Healthy Places Index Score             18951.8
# 4               1.0     CDPH-Derived ZCTA Score               860.0
#
#    Age 5+ Population  Total Population  Fully Vaccinated  \
# 0              28588           31470.0              51.0
# 1              13932           14859.0              66.0
# 2              37870           40861.0             114.0
# 3              20522           21331.0             155.0
# 4               1032            1074.0               NaN
#
#    Partially Vaccinated  Percent Fully Vaccinated  \
# 0                 252.0                  0.001621
# 1                 317.0                  0.004442
# 2                 835.0                  0.002790
# 3                 441.0                  0.007266
# 4                   NaN                       NaN
#
#    Percent Partially Vaccinated  Percent With 1+ Dose  Up To Date Count
# 0                      0.008008              0.009629                 0
# 1                      0.021334              0.025776                 0
# 2                      0.020435              0.023225                 0
# 3                      0.020674              0.027940                 0
# 4                           NaN                   NaN                 0

# %%
#HPI File
url = "https://api.healthyplacesindex.org/api/hpi?geography=zips&year=2022&indicator=hpi2score&format=json&key=721a0a48-97f3-4a3f-a794-2bc855972617"
data = requests.get(url).json()
hpi_df = pd.DataFrame(data)
hpi_df
# Out:
#       geoid   name  population     value  percentile numerator denominator
# 0     94601  94601       53039 -0.380256    0.246002      None        None
# 1     94501  94501       63821  0.584656    0.860625      None        None
# 2     94560  94560       47171  0.389073    0.740289      None        None
# 3     94587  94587       74722  0.448256    0.783701      None        None
# 4     94580  94580       30488  0.246554    0.654227      None        None
# ...     ...    ...         ...       ...         ...       ...         ...
# 1308  93274  93274       74000 -0.566216    0.150038      None        None
# 1309  95370  95370       28096  0.040532    0.525514      None        None
# 1310  95372  95372        2056 -0.000992    0.501904      None        None
# 1311  95627  95627        3802 -0.119862    0.418126      None        None
# 1312  95903  95903        1653 -1.070441    0.015232      None        None
#
# [1313 rows x 7 columns]

# %%
column_name_mapping = {
    'geoid': 'Zip Codes',
    'name': 'Location Name',
    'population': 'Population',
    'value': 'HPI Value',
    'percentile': 'HPI Percentile',
    'numerator': 'Numerator',
    'denominator': 'Denominator'
}

# Rename the columns using the dictionary
hpi_df.rename(columns=column_name_mapping, inplace=True)

# %%
hpi_df.head()
# Out:
#   Zip Codes Location Name  Population  HPI Value  HPI Percentile Numerator  \
# 0     94601         94601       53039  -0.380256        0.246002      None
# 1     94501         94501       63821   0.584656        0.860625      None
# 2     94560         94560       47171   0.389073        0.740289      None
# 3     94587         94587       74722   0.448256        0.783701      None
# 4     94580         94580       30488   0.246554        0.654227      None
#
#   Denominator
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
