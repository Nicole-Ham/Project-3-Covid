# %%
import pandas as pd
import numpy as np
import requests #api
import json #json file
from datetime import datetime

import matplotlib.pyplot as plt
from scipy.stats import linregress #stastistical analysis

from pathlib import Path #reading csv - connecting to the csv merges mac and windows

# %%
covid_vaccines_path = Path("COVID-19_Vaccines_Up_to_Date_Status.csv")
covid_vaccines_df = pd.read_csv(covid_vaccines_path)
covid_vaccines_df.head()
# Out:
#          Date Location   Demographic_Category     census  Up_to_date  \
# 0  09/13/2023       AK  Female_Ages_12-17_yrs    27938.0      2697.0
# 1  09/13/2023       AK    Female_Ages_75+_yrs    16346.0      7344.0
# 2  09/13/2023       AK    Male_Ages_12-17_yrs    29377.0      2598.0
# 3  09/13/2023       CA      Male_Ages_65+_yrs  2602393.0   1331083.0
# 4  09/13/2023       CT      Male_Ages_65+_yrs   276002.0    175897.0
#
#    Up_to_date_pct_agegroup
# 0                      9.7
# 1                     44.9
# 2                      8.8
# 3                     51.1
# 4                     63.7

# %%
hospitalizations_path = "https://data.cdc.gov/resource/n8mc-b4w4.json"
hospitalization_data = requests.get(hospitalizations_path).json()
#hospitalization_data

# %%
hospitalization_df = pd.DataFrame(hospitalization_data)
hospitalization_df.head()
# Out:
#   case_month res_state state_fips_code  res_county county_fips_code  \
# 0    2021-12        FL              12   CHARLOTTE            12015
# 1    2020-11        MI              26     ALLEGAN            26005
# 2    2021-03        OH              39      MEDINA            39103
# 3    2022-10        RI              44  WASHINGTON            44009
# 4    2020-08        WA              53      YAKIMA            53077
#
#         age_group     sex     race            ethnicity case_onset_interval  \
# 0  50 to 64 years  Female    White  Non-Hispanic/Latino                 0.0
# 1       65+ years  Female    White  Non-Hispanic/Latino                 0.0
# 2              NA      NA       NA                   NA                 0.0
# 3  18 to 49 years  Female  Unknown              Unknown                 NaN
# 4    0 - 17 years    Male       NA                   NA                 0.0
#
#    process exposure_yn             current_status symptom_status  hosp_yn  \
# 0  Missing     Missing  Laboratory-confirmed case    Symptomatic       No
# 1  Missing     Missing  Laboratory-confirmed case    Symptomatic       No
# 2  Unknown     Unknown  Laboratory-confirmed case    Symptomatic       No
# 3  Missing     Missing  Laboratory-confirmed case        Missing  Missing
# 4  Missing     Missing  Laboratory-confirmed case    Symptomatic       No
#
#     icu_yn death_yn case_positive_specimen underlying_conditions_yn
# 0  Missing       No                    NaN                      NaN
# 1  Missing       No                    NaN                      NaN
# 2       No       NA                    1.0                      NaN
# 3  Missing       No                    NaN                      NaN
# 4  Missing  Missing                    0.0                      NaN

# %%
hospitalization_df.age_group.value_counts()
# Out:
# 18 to 49 years    444
# 50 to 64 years    203
# 0 - 17 years      202
# 65+ years         125
# Missing            15
# NA                 11
# Name: age_group, dtype: int64

# %%
covid_vaccines_df.Demographic_Category.value_counts()
# Out:
# Female_Ages_12-17_yrs    236
# Ages_50-64_yrs           236
# Male_Ages_2-4_yrs        236
# Ages_25-39_yrs           236
# Male_Ages_25-39_yrs      236
# Sex_Unknown              236
# Female_Ages_25-49_yrs    236
# Female_Ages_18-24_yrs    236
# Male_Ages_65-74_yrs      236
# Ages_25-49_yrs           236
# Female_Ages_25-39_yrs    236
# Ages_18-24_yrs           236
# Ages_65-74_yrs           236
# Female_Ages_40-49_yrs    236
# Male_Ages_25-49_yrs      236
# Male_Ages_<2yrs          236
# Sex_Female               236
# Male_Ages_75+_yrs        236
# Male_Ages_50-64_yrs      236
# Age_Unknown              236
# Male_Ages_<5yrs          236
# Female_Ages_50-64_yrs    236
# Female_Ages_75+_yrs      236
# Ages_<2yrs               236
# Male_Ages_12-17_yrs      236
# Male_Ages_65+_yrs        236
# Ages_75+_yrs             236
# Female_Ages_2-4_yrs      236
# Female_Ages_65-74_yrs    236
# Ages_12-17_yrs           236
# Female_Ages_<2yrs        236
# Sex_Male                 236
# Female_Ages_<5yrs        236
# Ages_65+_yrs             236
# Male_Ages_18-24_yrs      236
# Ages_<5yrs               236
# Female_Ages_5-11_yrs     236
# Male_Ages_5-11_yrs       236
# Ages_5-11_yrs            236
# Female_Ages_65+_yrs      236
# Ages_40-49_yrs           236
# Ages_2-4_yrs             236
# Male_Ages_40-49_yrs      236
# Name: Demographic_Category, dtype: int64

# %%
covid_vaccines_df.set_index('Location').sort_index().head(20)
# Out:
#                 Date   Demographic_Category    census  Up_to_date  \
# Location
# AK        09/13/2023  Female_Ages_12-17_yrs   27938.0      2697.0
# AK        09/13/2023  Female_Ages_25-39_yrs   80186.0      9014.0
# AK        07/12/2023      Male_Ages_2-4_yrs   15880.0        53.0
# AK        07/12/2023  Female_Ages_25-49_yrs  121096.0     15552.0
# AK        07/12/2023           Ages_2-4_yrs   31090.0        94.0
# AK        09/13/2023  Female_Ages_65-74_yrs   29793.0     13587.0
# AK        07/12/2023             Sex_Female  350127.0     60375.0
# AK        07/12/2023    Male_Ages_65-74_yrs   31507.0     13996.0
# AK        07/12/2023  Female_Ages_40-49_yrs   40910.0      6725.0
# AK        07/12/2023         Ages_12-17_yrs   57315.0      4992.0
# AK        07/12/2023      Male_Ages_75+_yrs   13942.0      7820.0
# AK        07/12/2023  Female_Ages_18-24_yrs   29602.0      2548.0
# AK        09/13/2023    Male_Ages_50-64_yrs   70478.0     12340.0
# AK        09/13/2023            Age_Unknown       NaN         NaN
# AK        07/12/2023         Ages_25-49_yrs  255656.0     27138.0
# AK        07/12/2023            Sex_Unknown       NaN       693.0
# AK        07/12/2023     Male_Ages_5-11_yrs   36851.0      1705.0
# AK        07/12/2023   Female_Ages_5-11_yrs   34737.0      1560.0
# AK        07/12/2023           Ages_75+_yrs   30288.0     15881.0
# AK        07/12/2023         Ages_25-39_yrs  170009.0     15182.0
#
#           Up_to_date_pct_agegroup
# Location
# AK                            9.7
# AK                           11.2
# AK                            0.3
# AK                           12.8
# AK                            0.3
# AK                           45.6
# AK                           17.2
# AK                           44.4
# AK                           16.4
# AK                            8.7
# AK                           56.1
# AK                            8.6
# AK                           17.5
# AK                            NaN
# AK                           10.6
# AK                            NaN
# AK                            4.6
# AK                            4.5
# AK                           52.4
# AK                            8.9

# %%
no_general_gender = covid_vaccines_df.loc[covid_vaccines_df['Demographic_Category'].str.contains('yrs')]
no_general_gender
# Out:
#              Date Location   Demographic_Category     census  Up_to_date  \
# 0      09/13/2023       AK  Female_Ages_12-17_yrs    27938.0      2697.0
# 1      09/13/2023       AK    Female_Ages_75+_yrs    16346.0      7344.0
# 2      09/13/2023       AK    Male_Ages_12-17_yrs    29377.0      2598.0
# 3      09/13/2023       CA      Male_Ages_65+_yrs  2602393.0   1331083.0
# 4      09/13/2023       CT      Male_Ages_65+_yrs   276002.0    175897.0
# ...           ...      ...                    ...        ...         ...
# 10141  06/14/2023       TX    Male_Ages_65-74_yrs  1046971.0         NaN
# 10142  06/14/2023       WI         Ages_25-49_yrs  1797281.0    285589.0
# 10143  06/14/2023       VI     Male_Ages_5-11_yrs     5225.0        12.0
# 10146  06/14/2023       WI        Male_Ages_<2yrs    65295.0      1663.0
# 10147  06/14/2023       WY  Female_Ages_25-39_yrs    55969.0         NaN
#
#        Up_to_date_pct_agegroup
# 0                          9.7
# 1                         44.9
# 2                          8.8
# 3                         51.1
# 4                         63.7
# ...                        ...
# 10141                      NaN
# 10142                     15.9
# 10143                      0.2
# 10146                      2.5
# 10147                      NaN
#
# [9204 rows x 6 columns]

# %%
no_general_gender.loc[(no_general_gender.Location == "AK")& (no_general_gender.Date == '09/13/2023')]
# Out:
#             Date Location   Demographic_Category    census  Up_to_date  \
# 0     09/13/2023       AK  Female_Ages_12-17_yrs   27938.0      2697.0
# 1     09/13/2023       AK    Female_Ages_75+_yrs   16346.0      7344.0
# 2     09/13/2023       AK    Male_Ages_12-17_yrs   29377.0      2598.0
# 30    09/13/2023       AK             Ages_<5yrs   51080.0       301.0
# 117   09/13/2023       AK      Female_Ages_<2yrs    9717.0        73.0
# 160   09/13/2023       AK    Male_Ages_25-49_yrs  134560.0     11458.0
# 234   09/13/2023       AK         Ages_50-64_yrs  136166.0     27624.0
# 335   09/13/2023       AK         Ages_40-49_yrs   85647.0     12070.0
# 416   09/13/2023       AK         Ages_25-49_yrs  255656.0     27595.0
# 489   09/13/2023       AK           Ages_2-4_yrs   31090.0       160.0
# 515   09/13/2023       AK         Ages_18-24_yrs   68152.0      4488.0
# 516   09/13/2023       AK        Male_Ages_<5yrs   26153.0       156.0
# 598   09/13/2023       AK    Male_Ages_50-64_yrs   70478.0     12340.0
# 688   09/13/2023       AK  Female_Ages_65-74_yrs   29793.0     13587.0
# 769   09/13/2023       AK  Female_Ages_25-39_yrs   80186.0      9014.0
# 906   09/13/2023       AK          Ages_5-11_yrs   71588.0      3619.0
# 961   09/13/2023       AK    Female_Ages_2-4_yrs   15210.0        69.0
# 1045  09/13/2023       AK    Male_Ages_25-39_yrs   89823.0      6301.0
# 1123  09/13/2023       AK     Male_Ages_5-11_yrs   36851.0      1867.0
# 1205  09/13/2023       AK             Ages_<2yrs   19990.0       141.0
# 1288  09/13/2023       AK        Male_Ages_<2yrs   10273.0        68.0
# 1307  09/13/2023       AK   Female_Ages_5-11_yrs   34737.0      1721.0
# 1308  09/13/2023       AK    Female_Ages_65+_yrs   46139.0     20908.0
# 1345  09/13/2023       AK  Female_Ages_18-24_yrs   29602.0      2674.0
# 1509  09/13/2023       AK      Male_Ages_75+_yrs   13942.0      7059.0
# 1571  09/13/2023       AK      Female_Ages_<5yrs   24927.0       142.0
# 1910  09/13/2023       AK  Female_Ages_25-49_yrs  121096.0     15797.0
# 1991  09/13/2023       AK      Male_Ages_65+_yrs   45449.0     19854.0
# 2016  09/13/2023       AK         Ages_12-17_yrs   57315.0      5315.0
# 2017  09/13/2023       AK         Ages_65-74_yrs   61300.0     26477.0
# 2079  09/13/2023       AK  Female_Ages_50-64_yrs   65688.0     15123.0
# 2137  09/13/2023       AK  Female_Ages_40-49_yrs   40910.0      6784.0
# 2212  09/13/2023       AK           Ages_65+_yrs   91588.0     40846.0
# 2274  09/13/2023       AK    Male_Ages_65-74_yrs   31507.0     12831.0
# 2302  09/13/2023       AK    Male_Ages_40-49_yrs   44737.0      5159.0
# 2339  09/13/2023       AK    Male_Ages_18-24_yrs   38550.0      1765.0
# 2340  09/13/2023       AK      Male_Ages_2-4_yrs   15880.0        88.0
# 2386  09/13/2023       AK           Ages_75+_yrs   30288.0     14428.0
# 2443  09/13/2023       AK         Ages_25-39_yrs  170009.0     15528.0
#
#       Up_to_date_pct_agegroup
# 0                         9.7
# 1                        44.9
# 2                         8.8
# 30                        0.6
# 117                       0.8
# 160                       8.5
# 234                      20.3
# 335                      14.1
# 416                      10.8
# 489                       0.5
# 515                       6.6
# 516                       0.6
# 598                      17.5
# 688                      45.6
# 769                      11.2
# 906                       5.1
# 961                       0.5
# 1045                      7.0
# 1123                      5.1
# 1205                      0.7
# 1288                      0.7
# 1307                      5.0
# 1308                     45.3
# 1345                      9.0
# 1509                     50.6
# 1571                      0.6
# 1910                     13.0
# 1991                     43.7
# 2016                      9.3
# 2017                     43.2
# 2079                     23.0
# 2137                     16.6
# 2212                     44.6
# 2274                     40.7
# 2302                     11.5
# 2339                      4.6
# 2340                      0.6
# 2386                     47.6
# 2443                      9.1

# %%
minus_male = no_general_gender.loc[~no_general_gender['Demographic_Category'].str.contains('Male')]
minus_male
# Out:
#              Date Location   Demographic_Category     census  Up_to_date  \
# 0      09/13/2023       AK  Female_Ages_12-17_yrs    27938.0      2697.0
# 1      09/13/2023       AK    Female_Ages_75+_yrs    16346.0      7344.0
# 5      09/13/2023       DE           Ages_75+_yrs    76048.0         NaN
# 6      09/13/2023       HI    Female_Ages_2-4_yrs    25076.0       519.0
# 7      09/13/2023       IA  Female_Ages_65-74_yrs   161188.0     89956.0
# ...           ...      ...                    ...        ...         ...
# 10134  06/14/2023       PA           Ages_75+_yrs  1039269.0    516640.0
# 10136  06/14/2023       WA           Ages_2-4_yrs   280089.0     11859.0
# 10137  06/14/2023       TN           Ages_65+_yrs  1143393.0         NaN
# 10142  06/14/2023       WI         Ages_25-49_yrs  1797281.0    285589.0
# 10147  06/14/2023       WY  Female_Ages_25-39_yrs    55969.0         NaN
#
#        Up_to_date_pct_agegroup
# 0                          9.7
# 1                         44.9
# 5                          NaN
# 6                          2.1
# 7                         55.8
# ...                        ...
# 10134                     49.7
# 10136                      4.2
# 10137                      NaN
# 10142                     15.9
# 10147                      NaN
#
# [6136 rows x 6 columns]

# %%
minus_female = minus_male.loc[~minus_male['Demographic_Category'].str.contains('Female')]
minus_female
# Out:
#              Date Location Demographic_Category     census  Up_to_date  \
# 5      09/13/2023       DE         Ages_75+_yrs    76048.0         NaN
# 8      09/13/2023       ID       Ages_12-17_yrs   156543.0         NaN
# 11     09/13/2023       KY           Ages_<2yrs   107266.0       812.0
# 14     09/13/2023       MA           Ages_<5yrs   357362.0     15956.0
# 20     09/13/2023       ND        Ages_5-11_yrs    70715.0      3728.0
# ...           ...      ...                  ...        ...         ...
# 10133  06/14/2023       PR           Ages_<5yrs   117482.0       240.0
# 10134  06/14/2023       PA         Ages_75+_yrs  1039269.0    516640.0
# 10136  06/14/2023       WA         Ages_2-4_yrs   280089.0     11859.0
# 10137  06/14/2023       TN         Ages_65+_yrs  1143393.0         NaN
# 10142  06/14/2023       WI       Ages_25-49_yrs  1797281.0    285589.0
#
#        Up_to_date_pct_agegroup
# 5                          NaN
# 8                          NaN
# 11                         0.8
# 14                         4.5
# 20                         5.3
# ...                        ...
# 10133                      0.2
# 10134                     49.7
# 10136                      4.2
# 10137                      NaN
# 10142                     15.9
#
# [3068 rows x 6 columns]

# %%
minus_female['Date'] = pd.to_datetime(minus_female["Date"])
# Out:
# /var/folders/sb/9p37yr6j5fv_p4p8r67x7jlw0000gn/T/ipykernel_33857/3248847713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   minus_female['Date'] = pd.to_datetime(minus_female["Date"])

# %%
minus_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3068 entries, 5 to 10142
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     3068 non-null   datetime64[ns]
#  1   Location                 3068 non-null   object
#  2   Demographic_Category     3068 non-null   object
#  3   census                   3068 non-null   float64
#  4   Up_to_date               2385 non-null   float64
#  5   Up_to_date_pct_agegroup  2385 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 167.8+ KB

# %%
minus_female['Date'].dt.year
# Out:
# 5        2023
# 8        2023
# 11       2023
# 14       2023
# 20       2023
#          ...
# 10133    2023
# 10134    2023
# 10136    2023
# 10137    2023
# 10142    2023
# Name: Date, Length: 3068, dtype: int64

# %%
minus_female['Date'].dt.month
# Out:
# 5        9
# 8        9
# 11       9
# 14       9
# 20       9
#         ..
# 10133    6
# 10134    6
# 10136    6
# 10137    6
# 10142    6
# Name: Date, Length: 3068, dtype: int64

# %%
#minus_female["Date"].iloc[0].month

# %%
#minus_female["Date"].iloc[0].year

# %%
#minus_female['year'] = minus_female["Date"].dt.year
#minus_female['month'] = minus_female["Date"].dt.month
#minus_female

# %%
# delete old date column 
del minus_female['Date']
minus_female.head()

# %%
#drop rows with NaN
minus_female.dropna(how = 'any')
minus_female.head()

# %% [markdown]
# #### HELP DROP THE NaN

# %%
#with Nan strings, frst conert them to real NA value:
# minus_female_nan = minus_female.replace('Nan', pd.NA).dropna(axis=1)
# minus_female.head()
#hmm this removed the entire column?

# %%
#group by month and state -- didnt seem to work? 
vaccines_grouped = minus_female.groupby(['month', 'Location'])
vaccines_grouped.head()

# %%
#grouping age demographic category into similar categories to other db
minus_female.Demographic_Category.value_counts()
# Out:
# Ages_75+_yrs      236
# Ages_12-17_yrs    236
# Ages_<2yrs        236
# Ages_<5yrs        236
# Ages_5-11_yrs     236
# Ages_40-49_yrs    236
# Ages_2-4_yrs      236
# Ages_65+_yrs      236
# Ages_18-24_yrs    236
# Ages_25-39_yrs    236
# Ages_25-49_yrs    236
# Ages_50-64_yrs    236
# Ages_65-74_yrs    236
# Name: Demographic_Category, dtype: int64

# %%
#age groups: 
# 0 - 17 
# 18 - 49
# 50 -64
# 65+
